# %% [markdown]
# ## Aplicação dos métodos

# %% [markdown]
# ### Importação

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import sklearn.decomposition
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset
from torch.nn import functional as F
import torchvision
from torchvision import datasets,transforms
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dados tratados/v1/data.csv')

# %%
df = df.drop(['Mau', 'Maa', 'Mag'], axis=1)

# %%
df['Abs 1º Pico'] = df['Abs 1º Pico'].replace(np.nan,0)

# %%
df['Abs 2º Pico'] = df['Abs 2º Pico'].replace(np.nan,0)

# %%
df['Resultado 2'] = list(df['Resultado'].replace('FI','NF'))

# %% [markdown]
# ### Absorbância 1º Pico

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(df.columns)[1:9]
TARGET = ['Abs 1º Pico']
# TARGET = ['Resultado']

indices = df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = df.loc[indices_treino]
df_teste = df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGET, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGET, axis=1)

# %%
normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X_treino)
normalizador_y.fit(y_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = normalizador_y.transform(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = normalizador_y.transform(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.float32)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.float32)

# %%
class MLP(nn.Module):
    def __init__(
        self, num_dados_entrada, neuronios_c1, neuronios_c2, num_targets
    ):
        # Temos que inicializar a classe mãe
        super().__init__()

        # Definindo as camadas da rede
        self.camadas = nn.Sequential(
                    nn.Linear(num_dados_entrada, neuronios_c1),
                    nn.ReLU(),
                    nn.Linear(neuronios_c1, neuronios_c2),
                    nn.ReLU(),
                    nn.Linear(neuronios_c2, num_targets),
                )

    def forward(self, x):
        """Esse é o método que executa a rede do pytorch."""
        x = self.camadas(x)
        return x

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
TAXA_DE_APRENDIZADO = 0.01

# função perda será o erro quadrático médio
fn_perda = nn.MSELoss()

# otimizador será o Adam, um tipo de descida do gradiente
otimizador = optim.Adam(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
minha_MLP.train()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=8, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
NUM_EPOCAS = 10000

y_true = y_treino

for epoca in range(NUM_EPOCAS):
    # forward pass
    y_pred = minha_MLP(X_treino)

    # zero grad
    otimizador.zero_grad()

    # loss
    loss = fn_perda(y_pred, y_true)

    # backpropagation
    loss.backward()

    # atualiza parâmetros
    otimizador.step()

    # mostra resultado

print(epoca, loss.data)
# Out:
# 9999 tensor(4.9258e-06)

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_treino)
    y_pred = minha_MLP(X_treino)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
minha_MLP.eval()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=8, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_teste)
    y_pred = minha_MLP(X_teste)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
RMSE = mean_squared_error(y_true, y_pred, squared=False)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.17046460917155062

# %%
RMSE = mean_squared_error(y_true, y_pred)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.0290581829800095

# %% [markdown]
# ### Absorbância 1º e 2º pico

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(df.columns)[1:9]
TARGET = ['Abs 1º Pico','Abs 2º Pico']
# TARGET = ['Resultado']

indices = df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = df.loc[indices_treino]
df_teste = df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGET, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGET, axis=1)

# %%
normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X_treino)
normalizador_y.fit(y_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = normalizador_y.transform(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = normalizador_y.transform(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.float32)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.float32)

# %%
print(X_treino)
print()
print(y_treino)
# Out:
# tensor([[0.0000, 1.0000, 1.0000, 0.5714, 0.0000, 0.5000, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.0521, 0.5000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 0.1667, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000, 0.0667],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 0.5000, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000, 0.0333],
#         [0.0000, 0.0000, 0.0000, 0.4286, 1.0000, 0.1667, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.7917, 0.1667, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 0.8333, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.1042, 0.5000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 0.6667, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.0000, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000, 1.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.8333, 0.1667, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.1667, 0.0000, 0.0000],
#         [0.3333, 1.0000, 1.0000, 0.4286, 0.0000, 0.5000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 1.0000, 0.7143, 0.0000, 0.5000, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000, 0.3333],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.0667, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.8542, 0.1667, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.3333, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.1667, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.1429, 1.0000, 0.1667, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.0000, 0.5000, 0.0000, 0.0000],
#         [0.6667, 1.0000, 1.0000, 0.4286, 0.0000, 0.5000, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000, 0.6667]])
#
# tensor([[0.8184, 0.5109],
#         [0.3465, 1.0000],
#         [0.1081, 0.1025],
#         [0.3212, 0.1162],
#         [0.2069, 0.1113],
#         [0.4156, 0.2674],
#         [0.0907, 0.0916],
#         [0.0000, 0.0000],
#         [0.3170, 0.1107],
#         [0.3296, 0.4064],
#         [0.1922, 0.1045],
#         [0.6535, 0.1838],
#         [0.0000, 0.0000],
#         [0.0460, 0.0000],
#         [0.0946, 0.0990],
#         [0.7252, 0.5128],
#         [0.8992, 0.5198],
#         [0.0000, 0.0000],
#         [0.5569, 0.1869],
#         [0.3163, 0.1151],
#         [0.0388, 0.0388],
#         [0.7026, 0.3916],
#         [0.0885, 0.1355],
#         [0.0890, 0.1028],
#         [1.0000, 0.5165],
#         [0.9798, 0.0000],
#         [0.0000, 0.0000]])

# %%
class MLP(nn.Module):
    def __init__(
        self, num_dados_entrada, neuronios_c1, neuronios_c2, num_targets
    ):
        # Temos que inicializar a classe mãe
        super().__init__()

        # Definindo as camadas da rede
        self.camadas = nn.Sequential(
                    nn.Linear(num_dados_entrada, neuronios_c1),
                    nn.ReLU(),
                    nn.Linear(neuronios_c1, neuronios_c2),
                    nn.ReLU(),
                    nn.Linear(neuronios_c2, num_targets),
                )

    def forward(self, x):
        """Esse é o método que executa a rede do pytorch."""
        x = self.camadas(x)
        return x

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
for p in minha_MLP.parameters():
    print(p)
# Out:
# Parameter containing:
# tensor([[ 0.1594, -0.0367,  0.0212, -0.0502, -0.0328, -0.3176, -0.1819, -0.3105],
#         [-0.1301, -0.3120,  0.0852,  0.2343, -0.3464, -0.1947, -0.0359,  0.0113],
#         [ 0.1282, -0.0005,  0.1006,  0.0640, -0.1432,  0.3317, -0.0833,  0.0481],
#         [ 0.1021, -0.0413, -0.1954, -0.1289,  0.1165, -0.0666,  0.0300, -0.2727],
#         [-0.3517, -0.3059, -0.1314,  0.0480, -0.1282,  0.1540,  0.2776, -0.1893],
#         [ 0.0732, -0.2715, -0.1652, -0.0836, -0.0639,  0.1077,  0.1109, -0.2668],
#         [ 0.0260, -0.1926, -0.0419, -0.1126,  0.1493, -0.2980, -0.0274, -0.3232],
#         -0.1265,  0.0782, -0.1324,  0.1035,  0.0111, -0.0504,  0.0396, -0.0066,
#         -0.0713,  0.0189,  0.1050,  0.0384], requires_grad=True)
# Parameter containing:
# tensor([[-0.2170, -0.1949,  0.1189, -0.1039, -0.0030,  0.0905,  0.1532,  0.2101,
#           0.1895, -0.1719, -0.0972, -0.1596,  0.1469, -0.1347,  0.1266, -0.0943,
#          -0.1568,  0.1288, -0.1548,  0.2106],
#         [ 0.2226, -0.0290, -0.2032,  0.0888, -0.1017,  0.2099, -0.1283,  0.1847,
#           0.0208, -0.0461,  0.0481,  0.2131, -0.0477,  0.2177,  0.2191,  0.0728,
#           0.1270,  0.1522,  0.1507, -0.0393]], requires_grad=True)
# Parameter containing:
# tensor([-0.1948, -0.0225], requires_grad=True)

# %%
y_prev = minha_MLP(X_treino)
y_prev
# Out:
# tensor([[-0.0488,  0.0862],
#         [-0.0836,  0.1284],
#         [-0.0779,  0.0375],
#         [-0.0714,  0.0926],
#         [-0.0944,  0.0302],
#         [-0.0747,  0.0920],
#         [-0.0896,  0.0232],
#         [-0.1160,  0.0067],
#         [-0.0946,  0.0208],
#         [-0.0853,  0.1298],
#         [-0.0965,  0.0255],
#         [-0.0710,  0.1310],
#         [ 0.0184,  0.0988],
#         [-0.1142,  0.0070],
#         [-0.0695,  0.0585],
#         [-0.0657,  0.0979],
#         [-0.0402,  0.0866],
#         [-0.0453,  0.0975],
#         [-0.0748,  0.1306],
#         [-0.0879,  0.0172],
#         [-0.1133,  0.0071],
#         [-0.0838,  0.1309],
#         [-0.1050,  0.0098],
#         [-0.1010,  0.0142],
#         [-0.0821,  0.1270],
#         [-0.0722,  0.1105],
#         [-0.0139,  0.0983]], grad_fn=<AddmmBackward0>)

# %%
TAXA_DE_APRENDIZADO = 0.01

# função perda será o erro quadrático médio
fn_perda = nn.MSELoss()

# otimizador será o Adam, um tipo de descida do gradiente
otimizador = optim.Adam(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
minha_MLP.train()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=8, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
NUM_EPOCAS = 20000

y_true = y_treino

for epoca in range(NUM_EPOCAS):
    # forward pass
    y_pred = minha_MLP(X_treino)

    # zero grad
    otimizador.zero_grad()

    # loss
    loss = fn_perda(y_pred, y_true)

    # backpropagation
    loss.backward()

    # atualiza parâmetros
    otimizador.step()

    # mostra resultado

print(epoca, loss.data)
# Out:
# 19999 tensor(4.5581e-06)

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_treino)
    y_pred = minha_MLP(X_treino)
    y_pred = normalizador_y.inverse_transform(y_pred)

for yt, yp in zip(y_true, y_pred):
    print(yt, yp)
# Out:
# [3.3300001  4.01600023] [3.3457154  4.02697795]
# [1.40999997 7.86      ] [1.42792097 7.88136513]
# [0.44000001 0.80600002] [0.44562355 0.80978918]
# [1.30699996 0.91300001] [1.31860824 0.91744654]
# [0.84199998 0.875     ] [0.84963353 0.88038017]
# [1.69100001 2.10200009] [1.70581285 2.11768756]
# [0.369      0.72000002] [0.37478283 0.72318372]
# [0. 0.] [0.00367717 0.0003059 ]
# [1.28999997 0.87000002] [1.29857806 0.87518839]
# [1.34100006 3.19399991] [1.35950144 3.19923039]
# [0.78199998 0.82099997] [0.78755055 0.82475166]
# [2.65899991 1.44500002] [2.67275677 1.4546546 ]
# [0. 0.] [2.27749017e-03 7.46952742e-05]
# [0.187 0.   ] [0.17579733 0.00400974]
# [0.38500001 0.77799998] [0.3899337  0.78084548]
# [2.95100007 4.03099996] [2.96652377 4.04841054]
# [3.65900011 4.08600004] [3.67505495 4.0965102 ]
# [0. 0.] [ 0.00171611 -0.00099991]
# [2.26600001 1.46899995] [2.27881682 1.4791632 ]
# [1.28699998 0.90499998] [1.29908059 0.91144193]
# [0.158      0.30500001] [0.18808754 0.30733088]
# [2.85899995 3.07799999] [2.87895542 3.09432508]
# [0.36       1.06500001] [0.35938349 1.06738323]
# [0.362      0.80800001] [0.36786268 0.81089787]
# [4.069      4.06000011] [4.09027339 4.08127764]
# [3.98699993 0.        ] [4.00310231 0.01820776]
# [0. 0.] [0.00065664 0.00052304]

# %%
minha_MLP.eval()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=8, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_teste)
    y_pred = minha_MLP(X_teste)
    y_pred = normalizador_y.inverse_transform(y_pred)

for yt, yp in zip(y_true, y_pred):
    print(yt, yp)
# Out:
# [2.81999994 2.57399997] [2.45495299 2.1120598 ]
# [0.35399999 0.81499999] [0.35159199 0.77948334]
# [2.92599995 3.97300012] [3.0849375  4.10440336]
# [2.13000009 2.82999997] [2.31719012 2.75390039]

# %%
RMSE = mean_squared_error(y_true, y_pred, squared=False)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.2318787315317274

# %%
RMSE = mean_squared_error(y_true, y_pred)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.053909305306457184

# %% [markdown]
# ### Absorbância 1º e 2º pico normalizado

# %%
for column in df.columns[1:-2]:
    df[column] = df[column]/df[column].abs().max()

# %%
df['Abs 1º Pico'] = df['Abs 1º Pico'].replace(np.nan,0)
df['Abs 2º Pico'] = df['Abs 2º Pico'].replace(np.nan,0)

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(df.columns)[1:9]
TARGET = ['Abs 1º Pico','Abs 2º Pico']

indices = df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = df.loc[indices_treino]
df_teste = df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGET, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGET, axis=1)

# %%
normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X_treino)
normalizador_y.fit(y_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = normalizador_y.transform(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = normalizador_y.transform(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.float32)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.float32)

# %%
class MLP(nn.Module):
    def __init__(
        self, num_dados_entrada, neuronios_c1, neuronios_c2, num_targets
    ):
        # Temos que inicializar a classe mãe
        super().__init__()

        # Definindo as camadas da rede
        self.camadas = nn.Sequential(
                    nn.Linear(num_dados_entrada, neuronios_c1),
                    nn.ReLU(),
                    nn.Linear(neuronios_c1, neuronios_c2),
                    nn.ReLU(),
                    nn.Linear(neuronios_c2, num_targets),
                )

    def forward(self, x):
        """Esse é o método que executa a rede do pytorch."""
        x = self.camadas(x)
        return x

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
y_prev = minha_MLP(X_treino)

# %%
TAXA_DE_APRENDIZADO = 0.01

# função perda será o erro quadrático médio
fn_perda = nn.MSELoss()

# otimizador será o Adam, um tipo de descida do gradiente
otimizador = optim.Adam(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
minha_MLP.train()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=8, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
NUM_EPOCAS = 20000

y_true = y_treino

for epoca in range(NUM_EPOCAS):
    # forward pass
    y_pred = minha_MLP(X_treino)

    # zero grad
    otimizador.zero_grad()

    # loss
    loss = fn_perda(y_pred, y_true)

    # backpropagation
    loss.backward()

    # atualiza parâmetros
    otimizador.step()

    # mostra resultado

print(epoca, loss.data)
# Out:
# 19999 tensor(1.6404e-07)

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_treino)
    y_pred = minha_MLP(X_treino)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
minha_MLP.eval()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=8, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_teste)
    y_pred = minha_MLP(X_teste)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
y_true
# Out:
# array([[0.69304496, 0.32748091],
#        [0.08699926, 0.10368957],
#        [0.71909559, 0.50547075],
#        [0.52347016, 0.36005089]])

# %%
RMSE = mean_squared_error(y_true, y_pred, squared=False)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.04995381938273298

# %%
RMSE = mean_squared_error(y_true, y_pred)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.00249708663816009

# %%
y_true_1,y_true_2 = [],[]
y_pred_1,y_pred_2 = [],[]

for i in range(len(y_pred)):
    
    y_pred_1.append(y_pred[i][0])
    y_pred_2.append(y_pred[i][1])
    
    y_true_1.append(y_true[i][0])
    y_true_2.append(y_true[i][1])

# %%
model = LinearRegression()
m1 = model.fit(np.array(y_true_1).reshape((-1, 1)), y_pred_1)

model = LinearRegression()
m2 = model.fit(np.array(y_true_2).reshape((-1, 1)), y_pred_2)

# %%
def f(x,m):
    return m.intercept_ + x*m.coef_

# %%
x_plot_1 = np.linspace(min(y_true_1),max(y_true_1),10)
y_plot_1 = f(x_plot_1,m1)

x_plot_2 = np.linspace(min(y_true_2),max(y_true_2),10)
y_plot_2 = f(x_plot_2,m2)

# %%
s1,s2 = m1.score(np.array(y_true_1).reshape((-1, 1)),y_pred_1),m2.score(np.array(y_true_2).reshape((-1, 1)),y_pred_2)

# %%
plt.scatter(y_true_1,y_pred_1),plt.scatter(y_true_2,y_pred_2)
plt.plot(x_plot_1,y_plot_1,label=f'Abs 1º Pico - R²={round(s1,3)}')
plt.plot(x_plot_2,y_plot_2,label=f'Abs 2º Pico - R²={round(s2,3)}')

plt.title('Real por predito'),plt.xlabel('Real'),plt.ylabel('Predito')

plt.legend()
# plt.savefig('figs/realXpredito_pca.png')
plt.show()

# %% [markdown]
# ### Análise das épocas absorbância 1º e 2º pico - normalizados

# %%
X = df.iloc[:,1:9].values
y = df.iloc[:,-5:-3].values

normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X)
normalizador_y.fit(y)

X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

model = MLP(num_dados_entrada=X_tensor.shape[1], neuronios_c1=50, neuronios_c2=20, num_targets=y_tensor.shape[1])

num_epochs = 20000

loss_values, acc_values = [], []

dataset = TensorDataset(X_tensor, y_tensor)

# Define o otimizador
optimizer = optim.SGD(model.parameters(), lr=0.001)

criterion = nn.MSELoss()

min_loss = float('inf')
min_loss_value = None

for epoch in range(num_epochs):
    model.train()
    epoch_loss,num_batches = 0.0,0  # Variável para armazenar a perda da época atual

    train_loader = DataLoader(dataset, batch_size=64, shuffle=True)
    
    total,correct = 0,0
        
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # epoch_loss += loss.item()
        epoch_loss += np.sqrt(loss.item())
        
        mse = torch.mean((outputs - labels) ** 2)
        
        # _, predicted = torch.max(outputs.data,1)
        
        # total += labels.size(0)
        # correct += (predicted == labels).sum().item()

        num_batches += 1
    
    epoch_loss /= num_batches 
    
    # epoch_loss = np.sqrt(epoch_loss)
    epoch_loss = epoch_loss
    
    # print(epoch_loss,mse.item())
    
    loss_values.append(epoch_loss)
    acc_values.append(np.sqrt(mse.item()))
    
    if epoch_loss < min_loss:
        min_loss = epoch_loss
        min_loss_value = outputs
        min_loss_params = model.state_dict()
        min_loss_features = inputs

# %%
print(f"Valor mínimo da perda: {round(min_loss,4)}")

print()

for feature_values in min_loss_features:
    print(f"Valores das features: {feature_values}")

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

plt.figure(figsize=(6,4))

# plt.subplot(1,2,1)
plt.plot(range(1, num_epochs + 1), loss_values)
plt.xlabel('Época')
plt.ylabel('RMSE')
plt.title('RMSE através das épocas')

# plt.subplot(1,2,2)
# plt.plot(range(1, num_epochs + 1), acc_values)
# plt.xlabel('Época')
# plt.ylabel('Accuracy')
# plt.title('Gráfico de acurácia')

plt.tight_layout()
# plt.savefig('figs/rmse.png')
plt.show()
# Out:
# Valor mínimo da perda: 0.1408
#
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 0.8571, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.2586, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.2500, 0.8793, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 0.3333])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.5000, 1.0000, 1.0000, 0.5000, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 1.0000, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 0.0333])
# Valores das features: tensor([0.2500, 1.0000, 1.0000, 0.5000, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.4286, 0.0000, 0.0000])
# Valores das features: tensor([0.7500, 1.0000, 1.0000, 0.5000, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 0.7143, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 0.0667])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.2155, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 1.0000, 1.0000, 0.5833, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.3333, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.2500, 0.8276, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.2500, 0.8621, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.2000, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 1.0000, 1.0000, 0.6667, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.2500, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.1429, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.8333, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 1.0000, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 0.6667])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 1.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.5000, 1.0000, 0.2857, 0.0000, 0.0000])

# %%
df
# Out:
#    Amostra  Mctab     Qctab  Qau       Qag       Qaa     Qseed  Mhcl
# 0       T1   0.25  1.000000  1.0  0.500000  0.172414  0.571429   0.0  \
# 1       T2   0.25  1.000000  1.0  0.583333  0.172414  0.571429   0.0
# 2       T3   0.25  1.000000  1.0  0.666667  0.172414  0.571429   0.0
# 3       C1   0.50  1.000000  1.0  0.500000  0.172414  0.571429   0.0
# 4       C2   0.75  1.000000  1.0  0.500000  0.172414  0.571429   0.0
# 5       C3   1.00  1.000000  1.0  0.500000  0.172414  0.571429   0.0
# 6      AC1   1.00  1.000000  1.0  0.500000  0.215517  0.571429   0.0
# 7      AC2   1.00  1.000000  1.0  0.500000  0.258621  0.571429   0.0
# 8      AC3   1.00  1.000000  1.0  0.500000  0.344828  0.571429   0.0
# 9       S1   1.00  1.000000  1.0  0.500000  0.344828  0.142857   0.0
# 10      S2   1.00  1.000000  1.0  0.500000  0.344828  0.285714   0.0
# 11      S3   1.00  1.000000  1.0  0.500000  0.344828  0.428571   0.0
# 21  0.000000    0.805486    0.874582         NaN     0.038830     0.038804
# 22  0.000000    0.894015    0.876254         NaN     0.088965     0.102799
# 23  0.000000    0.937656    0.876254         NaN     0.090686     0.091603
# 24  0.000000    0.951372    0.877926         NaN     0.108135     0.102545
# 25  0.000000    0.983791    0.881271         NaN     0.094618     0.098982
# 26  0.000000    0.971322    0.879599         NaN     0.086999     0.103690
# 27  0.000000    0.948878    0.882943         NaN     0.206930     0.111323
# 28  0.000000    0.937656    0.877926         NaN     0.192185     0.104453
# 29  0.000000    1.000000    0.876254         NaN     0.317031     0.110687
# 30  0.000000    0.991272    0.877926         NaN     0.316294     0.115140
#
#     Abs 3º Pico Resultado Resultado 2
# 0           NaN        NF          NF
# 1           NaN        NF          NF
# 2           NaN        NF          NF
# 3           NaN        NF          NF
# 4           NaN        NF          NF
# 5        0.3999        NF          NF
# 6           NaN        NF          NF
# 7        1.0000        FI          NF
# 8        1.0000        FI          NF
# 9        0.1379        FI          NF
# 10          NaN        FI          NF
# 11          NaN        FI          NF
# 12       0.1385        FI          NF
# 13          NaN        NF          NF
# 14          NaN        NF          NF
# 15          NaN        NF          NF
# 16          NaN        FI          NF
# 17          NaN        FI          NF
# 18          NaN        NF          NF
# 19          NaN        NF          NF
# 20          NaN        FI          NF
# 21          NaN        FI          NF
# 22          NaN        FI          NF
# 23          NaN        FI          NF
# 24          NaN        FI          NF
# 25          NaN        FI          NF
# 26          NaN        FI          NF
# 27          NaN        FI          NF
# 28          NaN        FI          NF
# 29          NaN         F           F
# 30          NaN         F           F

# %%
features = df.iloc[-2:,1:9].columns
dados_reais = df.iloc[-2:,1:9].values
dados_preditos = list(min_loss_features)[-2:]

# %%
print('Valores reais:')

for f in features:
    print(f,end='\t')
print()

for r in dados_reais:
    for v in r:
        print(round(v,4),end='\t')
    print()

print()
print('Valores preditos:')

for f in features:
    print(f,end='\t')
print()

for r in dados_preditos:
    r = list(r)
    for v in r:
        print(round(v.item(),4),end='\t')
    print()
# Out:
# Valores reais:
# Mctab	Qctab	Qau	Qag	Qaa	Qseed	Mhcl	Qhcl
# 0.25	0.5063	0.5	0.6667	1.0	0.8571	0.0	0.0
# 0.25	0.5063	0.5	0.6667	1.0	1.0	0.0	0.0
#
# Valores preditos:
# Mctab	Qctab	Qau	Qag	Qaa	Qseed	Mhcl	Qhcl
# 1.0	1.0	1.0	0.5	0.3448	0.5714	1.0	1.0
# 0.25	0.5063	0.5	0.5	1.0	0.2857	0.0	0.0

# %% [markdown]
# ### Absorbância 1 e 2 - PCA

# %% [markdown]
# #### PCA

# %%
X = df.iloc[:,1:9]

# %%
pca = sklearn.decomposition.PCA(n_components=2)

# %%
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
X_pca = pca.transform(X)

# %% [markdown]
# #### Regressão

# %%
novo_df = pd.DataFrame(X_pca,columns=['PC1','PC2'])
novo_df['Target 1'] = df['Abs 1º Pico']
novo_df['Target 2'] = df['Abs 2º Pico']

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(novo_df.columns)[:2]
TARGETS = ['Target 1','Target 2']

indices = novo_df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = novo_df.loc[indices_treino]
df_teste = novo_df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGETS, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGETS, axis=1)

# %%
normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X_treino)
normalizador_y.fit(y_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = normalizador_y.transform(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = normalizador_y.transform(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.float32)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.float32)

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
y_prev = minha_MLP(X_treino)

# %%
TAXA_DE_APRENDIZADO = 0.01

# função perda será o erro quadrático médio
fn_perda = nn.MSELoss()

# otimizador será o Adam, um tipo de descida do gradiente
otimizador = optim.Adam(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
minha_MLP.train()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
NUM_EPOCAS = 20000

y_true = y_treino

for epoca in range(NUM_EPOCAS):
    # forward pass
    y_pred = minha_MLP(X_treino)

    # zero grad
    otimizador.zero_grad()

    # loss
    loss = fn_perda(y_pred, y_true)

    # backpropagation
    loss.backward()

    # atualiza parâmetros
    otimizador.step()

    # mostra resultado

print(epoca, loss.data)
# Out:
# 19999 tensor(9.8603e-05)

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_treino)
    y_pred = minha_MLP(X_treino)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
minha_MLP.train()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_treino)
    y_pred = minha_MLP(X_treino)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
RMSE = mean_squared_error(y_true, y_pred)
print(f'Loss do teste: {round(RMSE,6)}')
# Out:
# Loss do teste: 0.000108

# %%
y_pred
# Out:
# array([[ 8.28951001e-01,  5.19709408e-01],
#        [ 3.47986966e-01,  9.99746978e-01],
#        [ 9.17774439e-02,  1.04206532e-01],
#        [ 3.10691059e-01,  1.08594954e-01],
#        [ 1.85054690e-01,  1.07906640e-01],
#        [ 4.08002913e-01,  2.55819499e-01],
#        [ 9.01401043e-02,  1.05611771e-01],
#        [ 3.64363194e-04, -2.16099620e-03],
#        [ 2.86397904e-01,  1.11256957e-01],
#        [ 3.34463954e-01,  4.06701267e-01],
#        [ 2.31844574e-01,  1.09750122e-01],
#        [ 6.55430496e-01,  1.86597288e-01],
#        [-4.32360172e-03,  1.12667680e-03],
#        [ 3.08779478e-02,  1.62942708e-02],
#        [ 9.34153199e-02,  1.02801234e-01],
#        [ 7.31329441e-01,  5.14160395e-01],
#        [ 9.01060462e-01,  5.15922070e-01],
#        [-1.63739920e-03, -1.04355812e-03],
#        [ 5.58087647e-01,  1.91755444e-01],
#        [ 3.17471087e-01,  1.13512665e-01],
#        [ 4.13233638e-02,  2.63023973e-02],
#        [ 7.03050852e-01,  3.94712687e-01],
#        [ 8.76836777e-02,  1.07719600e-01],
#        [ 8.85025263e-02,  1.07016981e-01],
#        [ 1.00791907e+00,  5.17917037e-01],
#        [ 9.87361670e-01,  7.67499208e-04],
#        [-3.74674797e-03,  4.77164984e-04]])

# %% [markdown]
# #### Regressão através das épocas

# %%
X = novo_df.iloc[:,:2].values
y = novo_df.iloc[:,2:4].values

normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X)
normalizador_y.fit(y)

X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.float32)

model = MLP(num_dados_entrada=X_tensor.shape[1], neuronios_c1=50, neuronios_c2=20, num_targets=y_tensor.shape[1])

num_epochs = 20000

loss_values, acc_values = [], []

dataset = TensorDataset(X_tensor, y_tensor)

# Define o otimizador
optimizer = optim.SGD(model.parameters(), lr=0.001)

criterion = nn.MSELoss()

min_loss = float('inf')
min_loss_value = None

for epoch in range(num_epochs):
    model.train()
    epoch_loss,num_batches = 0.0,0  # Variável para armazenar a perda da época atual

    train_loader = DataLoader(dataset, batch_size=64, shuffle=True)
    
    total,correct = 0,0
        
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += np.sqrt(loss.item())
        
        mse = torch.mean((outputs - labels) ** 2)
        
        # _, predicted = torch.max(outputs.data,1)
        
        # total += labels.size(0)
        # correct += (predicted == labels).sum().item()

        num_batches += 1
    
    epoch_loss /= num_batches 
    epoch_loss = epoch_loss
    
    loss_values.append(epoch_loss)
    acc_values.append(np.sqrt(mse.item()))
    
    if epoch_loss < min_loss:
        min_loss = epoch_loss
        min_loss_value = outputs
        min_loss_params = model.state_dict()
        min_loss_features = inputs

# %%
print(f"Valor mínimo da perda: {round(min_loss,4)}")

print()

for feature_values in min_loss_features:
    print(f"Valores das features: {feature_values}")

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

plt.figure(figsize=(6,4))

# plt.subplot(1,2,1)
plt.plot(range(1, num_epochs + 1), loss_values)
plt.xlabel('Época')
plt.ylabel('RMSE')
plt.title('RMSE através das épocas PCA')

# plt.subplot(1,2,2)
# plt.plot(range(1, num_epochs + 1), acc_values)
# plt.xlabel('Época')
# plt.ylabel('Accuracy')
# plt.title('Gráfico de acurácia')

plt.tight_layout()
plt.savefig('figs/rmse_pca.png')
plt.show()
# Out:
# Valor mínimo da perda: 0.1572
#
# Valores das features: tensor([-0.7121,  0.1303])
# Valores das features: tensor([-0.6315,  0.0773])
# Valores das features: tensor([-0.7009,  0.1264])
# Valores das features: tensor([ 0.4659, -0.3595])
# Valores das features: tensor([ 0.1082, -0.3706])
# Valores das features: tensor([0.9666, 0.8473])
# Valores das features: tensor([ 0.4878, -0.3759])
# Valores das features: tensor([ 0.4140, -0.3376])
# Valores das features: tensor([ 0.3767, -0.3855])
# Valores das features: tensor([0.9107, 0.7158])
# Valores das features: tensor([ 0.1110, -0.3716])
# Valores das features: tensor([0.8547, 0.5842])
# Valores das features: tensor([0.8099, 0.4789])
# Valores das features: tensor([-0.6899,  0.1505])
# Valores das features: tensor([-0.6734,  0.1727])
# Valores das features: tensor([-0.6052,  0.0576])
# Valores das features: tensor([0.8043, 0.4657])
# Valores das features: tensor([ 0.4007, -0.3554])
# Valores das features: tensor([-0.6954,  0.1244])
# Valores das features: tensor([ 0.4222, -0.3266])
# Valores das features: tensor([-0.7065,  0.1284])
# Valores das features: tensor([ 0.3974, -0.3598])
# Valores das features: tensor([ 0.5096, -0.3924])
# Valores das features: tensor([-0.7176,  0.1323])
# Valores das features: tensor([ 0.4057, -0.3487])
# Valores das features: tensor([-0.6227,  0.0708])
# Valores das features: tensor([-0.6816,  0.1616])
# Valores das features: tensor([ 0.1054, -0.3696])
# Valores das features: tensor([ 0.2439, -0.3785])
# Valores das features: tensor([-0.6651,  0.1838])
# Valores das features: tensor([-0.6926,  0.1234])

# %% [markdown]
# ### Gráfico de Real x Predito PCA

# %%
y_true_1,y_true_2 = [],[]
y_pred_1,y_pred_2 = [],[]

for i in range(len(y_pred)):
    
    y_pred_1.append(y_pred[i][0])
    y_pred_2.append(y_pred[i][1])
    
    y_true_1.append(y_true[i][0])
    y_true_2.append(y_true[i][1])

# %%
model = LinearRegression()
m1 = model.fit(np.array(y_true_1).reshape((-1, 1)), y_pred_1)

model = LinearRegression()
m2 = model.fit(np.array(y_true_2).reshape((-1, 1)), y_pred_2)

# %%
def f(x,m):
    return m.intercept_ + x*m.coef_

# %%
x_plot_1 = np.linspace(min(y_true_1),max(y_true_1),10)
y_plot_1 = f(x_plot_1,m1)

x_plot_2 = np.linspace(min(y_true_2),max(y_true_2),10)
y_plot_2 = f(x_plot_2,m2)

# %%
s1,s2 = m1.score(np.array(y_true_1).reshape((-1, 1)),y_pred_1),m2.score(np.array(y_true_2).reshape((-1, 1)),y_pred_2)

# %%
plt.scatter(y_true_1,y_pred_1),plt.scatter(y_true_2,y_pred_2)
plt.plot(x_plot_1,y_plot_1,label=f'Abs 1º Pico - R²={round(s1,3)}')
plt.plot(x_plot_2,y_plot_2,label=f'Abs 2º Pico - R²={round(s2,3)}')

plt.title('Real por predito'),plt.xlabel('Real'),plt.ylabel('Predito')

plt.legend()
# plt.savefig('figs/realXpredito_pca.png')
plt.show()

# %% [markdown]
# ### Classificação

# %%
res_bool = []
for v in list(df['Resultado 2']):
    if v == 'NF':
        res_bool.append(False)
    else:
        res_bool.append(True)

# %%
df['Resultado Bool'] = res_bool

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(df.columns)[1:9]
TARGET = ['Resultado Bool']

indices = df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = df.loc[indices_treino]
df_teste = df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGET, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGET, axis=1)

# %%
normalizador_x = MinMaxScaler()

normalizador_x.fit(X_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = np.array(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = np.array(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.bool)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.bool)

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
y_prev = minha_MLP(X_treino)

# %%
TAXA_DE_APRENDIZADO = 0.01

criterion = nn.MSELoss()
optimizer = optim.SGD(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
dataset = TensorDataset(X_treino, y_treino)

# %%
num_epochs = 20000

for epoch in range(num_epochs):
    for inputs, labels in dataset:
        
        outputs = minha_MLP(inputs)
        
        loss = torch.sqrt(criterion(outputs, labels.float()))
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()
        
print(f'Época {epoch+1} - RMSE: {loss.item()}')
# Out:
# Época 20000 - RMSE: 0.002263946458697319

# %%
y_pred_pca = minha_MLP(X_treino)

# %%
y_pred_pca = np.array(y_pred_pca.detach().numpy()) > 0
y_pred_pca = y_pred_pca.tolist()

# %%
y_treino_pca = np.array(y_treino).copy()

# %%
cm = confusion_matrix(y_treino_pca,y_pred_pca)

sns.heatmap(cm, annot=True, fmt="d", cmap="viridis")

plt.xlabel('Valores Preditos')
plt.ylabel('Valores Verdadeiros')
plt.title('Matriz de Confusão')

plt.show()

# %% [markdown]
# ### Classificação PCA

# %%
novo_df['Resultado'] = list(df['Resultado Bool'])

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(novo_df.columns)[:2]
TARGET = ['Resultado']

indices = novo_df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = novo_df.loc[indices_treino]
df_teste = novo_df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGET, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGET, axis=1)

# %%
normalizador_x = MinMaxScaler()

normalizador_x.fit(X_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = np.array(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = np.array(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.bool)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.bool)

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
y_prev = minha_MLP(X_treino)

# %%
TAXA_DE_APRENDIZADO = 0.01

criterion = nn.MSELoss()
optimizer = optim.SGD(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
dataset = TensorDataset(X_treino, y_treino)

# %%
t, num_epochs = 0, 50

# %%
for epoch in range(num_epochs):
    for inputs, labels in dataset:
        
        outputs = minha_MLP(inputs)
        
        loss = torch.sqrt(criterion(outputs, labels.float()))
        
        optimizer.zero_grad()
        
        loss.backward()
        
        optimizer.step()

t += num_epochs

print(f'Época {t} - RMSE: {loss.item()}')
# Out:
# Época 50 - RMSE: 0.011541970074176788

# %%
y_pred = minha_MLP(X_treino)

# %%
y_pred = np.array(y_pred.detach().numpy()) > 0
y_pred = y_pred.tolist()

# %%
plt.figure(figsize=(14,4))

plt.subplot(121)
plt.scatter(y_true_1,y_pred_1),plt.scatter(y_true_2,y_pred_2)
plt.plot(x_plot_1,y_plot_1,label=f'Abs 1º Pico - R²={round(s1,3)}')
plt.plot(x_plot_2,y_plot_2,label=f'Abs 2º Pico - R²={round(s2,3)}')

plt.title('Real por predito'),plt.xlabel('Real'),plt.ylabel('Predito')

plt.legend()

cm = confusion_matrix(y_treino_pca,y_pred_pca)

plt.subplot(122)
sns.heatmap(cm, annot=True, fmt="d", cmap="viridis")

plt.xlabel('Valores Preditos')
plt.ylabel('Valores Verdadeiros')
plt.title('Matriz de confusão')

plt.savefig('figs/realXpredito_pca.png')

plt.show()
