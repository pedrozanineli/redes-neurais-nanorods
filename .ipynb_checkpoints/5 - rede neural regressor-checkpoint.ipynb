# %% [markdown]
# ## Aplicação dos métodos

# %% [markdown]
# ### Importação

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('dados tratados/v1/data.csv')

# %%
df = df.drop(['Mau', 'Maa', 'Mag'], axis=1)

# %%
df['Abs 1º Pico'] = df['Abs 1º Pico'].replace(np.nan,0)

# %%
df['Abs 2º Pico'] = df['Abs 2º Pico'].replace(np.nan,0)

# %%
df['Resultado 2'] = list(df['Resultado'].replace('FI','NF'))

# %% [markdown]
# ### Absorbância 1º Pico

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(df.columns)[1:8]
TARGET = ['Abs 1º Pico']
# TARGET = ['Resultado']

indices = df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = df.loc[indices_treino]
df_teste = df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGET, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGET, axis=1)

# %%
normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X_treino)
normalizador_y.fit(y_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = normalizador_y.transform(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = normalizador_y.transform(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.float32)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.float32)

# %%
class MLP(nn.Module):
    def __init__(
        self, num_dados_entrada, neuronios_c1, neuronios_c2, num_targets
    ):
        # Temos que inicializar a classe mãe
        super().__init__()

        # Definindo as camadas da rede
        self.camadas = nn.Sequential(
                    nn.Linear(num_dados_entrada, neuronios_c1),
                    nn.ReLU(),
                    nn.Linear(neuronios_c1, neuronios_c2),
                    nn.ReLU(),
                    nn.Linear(neuronios_c2, num_targets),
                )

    def forward(self, x):
        """Esse é o método que executa a rede do pytorch."""
        x = self.camadas(x)
        return x

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
TAXA_DE_APRENDIZADO = 0.01

# função perda será o erro quadrático médio
fn_perda = nn.MSELoss()

# otimizador será o Adam, um tipo de descida do gradiente
otimizador = optim.Adam(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
minha_MLP.train()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=7, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
NUM_EPOCAS = 20000

y_true = y_treino

for epoca in range(NUM_EPOCAS):
    # forward pass
    y_pred = minha_MLP(X_treino)

    # zero grad
    otimizador.zero_grad()

    # loss
    loss = fn_perda(y_pred, y_true)

    # backpropagation
    loss.backward()

    # atualiza parâmetros
    otimizador.step()

    # mostra resultado

print(epoca, loss.data)
# Out:
# 19999 tensor(0.0062)

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_treino)
    y_pred = minha_MLP(X_treino)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
minha_MLP.eval()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=7, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_teste)
    y_pred = minha_MLP(X_teste)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
RMSE = mean_squared_error(y_true, y_pred, squared=False)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.3559342161850026

# %%
RMSE = mean_squared_error(y_true, y_pred)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.12668916625123217

# %% [markdown]
# ### Absorbância 1º e 2º pico

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(df.columns)[1:8]
TARGET = ['Abs 1º Pico','Abs 2º Pico']
# TARGET = ['Resultado']

indices = df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = df.loc[indices_treino]
df_teste = df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGET, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGET, axis=1)

# %%
normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X_treino)
normalizador_y.fit(y_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = normalizador_y.transform(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = normalizador_y.transform(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.float32)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.float32)

# %%
print(X_treino)
print()
print(y_treino)
# Out:
# tensor([[0.0000, 1.0000, 1.0000, 0.5714, 0.0000, 0.5000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.0521, 0.5000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 0.1667, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 0.5000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000],
#         [0.0000, 0.0000, 0.0000, 0.4286, 1.0000, 0.1667, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.7917, 0.1667, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 0.8333, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.1042, 0.5000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 0.6667, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.0000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.8333, 0.1667, 0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000, 1.0000, 0.1667, 0.0000],
#         [0.3333, 1.0000, 1.0000, 0.4286, 0.0000, 0.5000, 0.0000],
#         [0.0000, 1.0000, 1.0000, 0.7143, 0.0000, 0.5000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.0667, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.7143, 1.0000, 1.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.8542, 0.1667, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.3333, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.1667, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.1429, 1.0000, 0.1667, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.0000, 0.5000, 0.0000],
#         [0.6667, 1.0000, 1.0000, 0.4286, 0.0000, 0.5000, 0.0000],
#         [1.0000, 1.0000, 1.0000, 0.4286, 0.2083, 0.5000, 1.0000]])
#
# tensor([[0.8184, 0.5109],
#         [0.3465, 1.0000],
#         [0.1081, 0.1025],
#         [0.3212, 0.1162],
#         [0.2069, 0.1113],
#         [0.4156, 0.2674],
#         [0.0907, 0.0916],
#         [0.0000, 0.0000],
#         [0.3170, 0.1107],
#         [0.3296, 0.4064],
#         [0.1922, 0.1045],
#         [0.6535, 0.1838],
#         [0.0000, 0.0000],
#         [0.0460, 0.0000],
#         [0.0946, 0.0990],
#         [0.7252, 0.5128],
#         [0.8992, 0.5198],
#         [0.0000, 0.0000],
#         [0.5569, 0.1869],
#         [0.3163, 0.1151],
#         [0.0388, 0.0388],
#         [0.7026, 0.3916],
#         [0.0885, 0.1355],
#         [0.0890, 0.1028],
#         [1.0000, 0.5165],
#         [0.9798, 0.0000],
#         [0.0000, 0.0000]])

# %%
class MLP(nn.Module):
    def __init__(
        self, num_dados_entrada, neuronios_c1, neuronios_c2, num_targets
    ):
        # Temos que inicializar a classe mãe
        super().__init__()

        # Definindo as camadas da rede
        self.camadas = nn.Sequential(
                    nn.Linear(num_dados_entrada, neuronios_c1),
                    nn.ReLU(),
                    nn.Linear(neuronios_c1, neuronios_c2),
                    nn.ReLU(),
                    nn.Linear(neuronios_c2, num_targets),
                )

    def forward(self, x):
        """Esse é o método que executa a rede do pytorch."""
        x = self.camadas(x)
        return x

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
for p in minha_MLP.parameters():
    print(p)
# Out:
# Parameter containing:
# tensor([[ 0.3433, -0.3471, -0.0207,  0.0592, -0.1046,  0.2684, -0.1089],
#         [ 0.2602,  0.0376,  0.2427,  0.3742, -0.2483, -0.0431,  0.0305],
#         [ 0.3504,  0.2221,  0.2350, -0.1696, -0.1168,  0.3069,  0.0615],
#         [ 0.1300, -0.2342, -0.0995, -0.3168,  0.3646,  0.0497,  0.0748],
#         [-0.0701, -0.2499, -0.0080,  0.0435,  0.3025,  0.2279, -0.0224],
#         [ 0.0432, -0.0049,  0.3744,  0.1019, -0.1323,  0.2307, -0.1888],
#         [ 0.3499, -0.0990,  0.0600,  0.1963,  0.1055, -0.1754,  0.0305],
#         [-0.2064, -0.2989,  0.1178,  0.2025, -0.1422,  0.2948, -0.2668],
#         [ 0.3097, -0.0748,  0.2930,  0.0025, -0.3567, -0.3774, -0.3579],
#           0.0351,  0.1007, -0.0769, -0.0326,  0.0361,  0.0151, -0.0338, -0.1320,
#           0.1013, -0.0689, -0.0233, -0.0386, -0.0377,  0.1347,  0.0357,  0.1299,
#           0.0467, -0.0645,  0.0300,  0.0349, -0.0051,  0.0993, -0.1050,  0.0629,
#          -0.0799, -0.0057],
#         [-0.0676, -0.0777, -0.1017,  0.0702,  0.1405, -0.1318,  0.0513, -0.0103,
#           0.1328,  0.1404, -0.0405,  0.0207, -0.0917,  0.0072,  0.0189, -0.1237,
#          -0.0322, -0.0147, -0.0114,  0.0762, -0.0718, -0.0518,  0.1137, -0.0622,
#           0.1096,  0.0798, -0.0596,  0.0668, -0.0776, -0.1053,  0.0491,  0.0414,
#          -0.0722, -0.0453, -0.0953,  0.1364,  0.0796, -0.1338, -0.0842, -0.0486,
#           0.1240,  0.0771, -0.0585, -0.0115,  0.0407,  0.0799,  0.0203, -0.0032,
#           0.0417,  0.0600],
#         [ 0.0520, -0.0924, -0.0710, -0.0384, -0.1015,  0.1390,  0.0623,  0.0058,
#          -0.1380,  0.0046,  0.0468, -0.1369,  0.0821,  0.0322,  0.0650, -0.0682,
#          -0.0357, -0.0161, -0.0949, -0.1260,  0.0556,  0.0292, -0.0453,  0.0697,
#           0.1297,  0.0952, -0.0937,  0.0912,  0.0097,  0.0874, -0.0649,  0.0474,
#          -0.0303, -0.1104, -0.1168, -0.0047,  0.0600,  0.1120, -0.1029, -0.1299,
#          -0.0371, -0.0996, -0.0702,  0.0023,  0.1144, -0.0632, -0.0154, -0.1167,
#           0.1032,  0.1386],
#         [-0.0647,  0.1060, -0.0257, -0.0651, -0.1276,  0.0517,  0.1236, -0.1394,
#           0.0394,  0.1337, -0.0066,  0.0194, -0.0315, -0.0042, -0.0117,  0.1065,
#           0.0583, -0.1309, -0.0493, -0.0569, -0.0690, -0.0945, -0.0813,  0.1164,
#          -0.1001, -0.0085, -0.0603, -0.0040, -0.0642,  0.1329, -0.0633, -0.0501,
#          -0.0155, -0.1299, -0.0817,  0.0802,  0.0263,  0.0237, -0.1312,  0.0723,
#          -0.1057, -0.1134, -0.1381, -0.0938, -0.1023,  0.0740, -0.0685,  0.0868,
#           0.0709, -0.0923],
#         [-0.0072,  0.0232, -0.0180, -0.0729,  0.0623,  0.1067, -0.0713, -0.1223,
#           0.0719,  0.0043, -0.1183,  0.0457, -0.0013, -0.1217, -0.1192, -0.0553,
#          -0.0897,  0.0288, -0.0366,  0.1167,  0.1267, -0.0956,  0.0444,  0.0249,
#          -0.0145, -0.0011, -0.0878,  0.0602,  0.1352,  0.0722,  0.0239,  0.1227,
#          -0.1083, -0.1342,  0.1380,  0.0312, -0.1379, -0.0798, -0.0601, -0.1163,
#           0.0327,  0.0366,  0.0652,  0.1201, -0.0948,  0.1373, -0.0249, -0.0462,
#           0.1202,  0.1093],
#         [-0.1067, -0.0604, -0.0309,  0.0744,  0.0739, -0.0528,  0.1170, -0.0165,
#           0.0974,  0.0048, -0.0612,  0.0196,  0.0727, -0.1037, -0.0061,  0.0132,
#           0.0169,  0.0505, -0.0963,  0.0286,  0.0574, -0.0659,  0.0238,  0.0390,
#           0.1103, -0.1142, -0.1358, -0.0481,  0.0668, -0.1084,  0.1304,  0.0204,
#           0.0796,  0.0536, -0.0059,  0.0597,  0.0095, -0.0740, -0.0044, -0.0631,
#          -0.1308, -0.0525,  0.1291, -0.0481, -0.0601, -0.1026, -0.0366, -0.0175,
#          -0.0088, -0.0944],
#         [-0.1386,  0.0056,  0.0341, -0.0195, -0.1059, -0.1324, -0.0364,  0.0166,
#           0.0446, -0.1234,  0.1037,  0.0478, -0.0243, -0.1303,  0.0700,  0.0631,
#           0.0657,  0.0561,  0.1336, -0.0832,  0.1380,  0.1082,  0.0603, -0.0961,
#           0.1374,  0.0262, -0.0812,  0.0709,  0.0858,  0.0608,  0.0365,  0.0348,
#          -0.0442,  0.1211, -0.1007, -0.1402,  0.0078,  0.0144,  0.0662,  0.0733,
#          -0.0321, -0.0828, -0.1108, -0.0676, -0.0290,  0.0906,  0.1019,  0.0652,
#           0.0265, -0.0975],
#         [-0.1262, -0.0522, -0.0802,  0.0543,  0.1238,  0.1341, -0.1368, -0.0470,
#          -0.1365, -0.1335, -0.0827, -0.0782, -0.1172, -0.0630, -0.0371,  0.0321,
#           0.0706, -0.0775,  0.1404,  0.1008,  0.0072, -0.0477,  0.0511,  0.1129,
#          -0.1172, -0.0669, -0.0813,  0.0351,  0.1341,  0.1165,  0.1281, -0.1179,
#           0.0044, -0.0081,  0.0400,  0.1271, -0.0787, -0.1371, -0.1384,  0.1181,
#          -0.0951,  0.0941, -0.0789, -0.0921, -0.0971, -0.0783, -0.1120, -0.0792,
#          -0.0957, -0.0733]], requires_grad=True)
# Parameter containing:
# tensor([ 0.0192, -0.0803,  0.0809, -0.1076, -0.0105, -0.0408, -0.0853,  0.0632,
#          0.0547, -0.0214, -0.1259,  0.0003, -0.0707, -0.1320, -0.0698,  0.0596,
#          0.1084, -0.0230, -0.1099, -0.0709], requires_grad=True)
# Parameter containing:
# tensor([[ 0.1545, -0.1542, -0.1058, -0.1791,  0.1447,  0.1880, -0.0600,  0.0263,
#          -0.1444, -0.1421, -0.1139,  0.2046,  0.1404,  0.1390, -0.1257,  0.1783,
#           0.0612, -0.2085, -0.0377, -0.0050],
#         [-0.1295,  0.0618, -0.1756, -0.0260,  0.1237, -0.1396, -0.1600,  0.1325,
#           0.0169, -0.0668, -0.0138,  0.1829, -0.0464, -0.1935,  0.1970,  0.2169,
#          -0.1309, -0.0245,  0.1692, -0.1092]], requires_grad=True)
# Parameter containing:
# tensor([-0.1213, -0.2077], requires_grad=True)

# %%
y_prev = minha_MLP(X_treino)
y_prev
# Out:
# tensor([[-0.0958, -0.3303],
#         [-0.1431, -0.2980],
#         [-0.1197, -0.2152],
#         [-0.0858, -0.3192],
#         [-0.1184, -0.2381],
#         [-0.0858, -0.3192],
#         [-0.1226, -0.2023],
#         [-0.1254, -0.1982],
#         [-0.1085, -0.2557],
#         [-0.1453, -0.2922],
#         [-0.1126, -0.2464],
#         [-0.1449, -0.2678],
#         [-0.0858, -0.3192],
#         [-0.1266, -0.1968],
#         [-0.1183, -0.2226],
#         [-0.1078, -0.3195],
#         [-0.0976, -0.3381],
#         [-0.0858, -0.3192],
#         [-0.1456, -0.2698],
#         [-0.1064, -0.2648],
#         [-0.1270, -0.1964],
#         [-0.1483, -0.2770],
#         [-0.1298, -0.1934],
#         [-0.1273, -0.1950],
#         [-0.1410, -0.3037],
#         [-0.1259, -0.3119],
#         [-0.0858, -0.3192]], grad_fn=<AddmmBackward0>)

# %%
TAXA_DE_APRENDIZADO = 0.01

# função perda será o erro quadrático médio
fn_perda = nn.MSELoss()

# otimizador será o Adam, um tipo de descida do gradiente
otimizador = optim.Adam(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
minha_MLP.train()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=7, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
NUM_EPOCAS = 10000

y_true = y_treino

for epoca in range(NUM_EPOCAS):
    # forward pass
    y_pred = minha_MLP(X_treino)

    # zero grad
    otimizador.zero_grad()

    # loss
    loss = fn_perda(y_pred, y_true)

    # backpropagation
    loss.backward()

    # atualiza parâmetros
    otimizador.step()

    # mostra resultado

print(epoca, loss.data)
# Out:
# 9999 tensor(0.0041)

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_treino)
    y_pred = minha_MLP(X_treino)
    y_pred = normalizador_y.inverse_transform(y_pred)

for yt, yp in zip(y_true, y_pred):
    print(yt, yp)
# Out:
# [3.3300001  4.01600023] [3.33280449 4.01830615]
# [1.40999997 7.86      ] [1.41175881 7.86359146]
# [0.44000001 0.80600002] [0.44130225 0.8037109 ]
# [1.30699996 0.91300001] [0.60006166 0.60285552]
# [0.84199998 0.875     ] [0.84247212 0.87521645]
# [1.69100001 2.10200009] [0.60006166 0.60285552]
# [0.369      0.72000002] [0.37082526 0.71747057]
# [0. 0.] [ 0.00110655 -0.00122247]
# [1.28999997 0.87000002] [1.29293339 0.86886825]
# [1.34100006 3.19399991] [1.342232   3.19736462]
# [0.78199998 0.82099997] [0.78356157 0.82016834]
# [2.65899991 1.44500002] [2.65995281 1.44487282]
# [0. 0.] [0.60006166 0.60285552]
# [0.187 0.   ] [0.18671819 0.00105815]
# [0.38500001 0.77799998] [0.38623149 0.77663567]
# [2.95100007 4.03099996] [2.95313144 4.03077977]
# [3.65900011 4.08600004] [3.66089161 4.08242404]
# [0. 0.] [0.60006166 0.60285552]
# [2.26600001 1.46899995] [2.26694539 1.46899738]
# [1.28699998 0.90499998] [1.29027088 0.90349137]
# [0.158      0.30500001] [0.16112587 0.29969161]
# [2.85899995 3.07799999] [2.86030113 3.07893229]
# [0.36       1.06500001] [0.36236532 1.05904933]
# [0.362      0.80800001] [0.36566156 0.80207083]
# [4.069      4.06000011] [4.07161497 4.06216923]
# [3.98699993 0.        ] [3.98937406e+00 6.97058290e-04]
# [0. 0.] [0.60006166 0.60285552]

# %%
minha_MLP.eval()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=7, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_teste)
    y_pred = minha_MLP(X_teste)
    y_pred = normalizador_y.inverse_transform(y_pred)

for yt, yp in zip(y_true, y_pred):
    print(yt, yp)
# Out:
# [2.81999994 2.57399997] [2.45865571 1.74899099]
# [0.35399999 0.81499999] [0.2611447  0.79180405]
# [2.92599995 3.97300012] [3.00471591 3.95418733]
# [2.13000009 2.82999997] [2.68920354 3.45194134]

# %%
RMSE = mean_squared_error(y_true, y_pred, squared=False)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.4276087394555561

# %%
RMSE = mean_squared_error(y_true, y_pred)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 0.19080491492074259

# %% [markdown]
# ### Absorbância 1º e 2º pico normalizado

# %%
for column in df.columns[1:-2]:
    df[column] = df[column]/df[column].abs().max()

# %%
TAMANHO_TESTE = 0.1
SEMENTE_ALEATORIA = 2319
FEATURES = list(df.columns)[1:8]
TARGET = ['Abs 1º Pico','Abs 2º Pico']

indices = df.index
indices_treino, indices_teste = train_test_split(indices, test_size=TAMANHO_TESTE, random_state=SEMENTE_ALEATORIA)

df_treino = df.loc[indices_treino]
df_teste = df.loc[indices_teste]

X_treino = df_treino.reindex(FEATURES, axis=1)
y_treino = df_treino.reindex(TARGET, axis=1)
X_teste = df_teste.reindex(FEATURES, axis=1)
y_teste = df_teste.reindex(TARGET, axis=1)

# %%
normalizador_x = MinMaxScaler()
normalizador_y = MinMaxScaler()

normalizador_x.fit(X_treino)
normalizador_y.fit(y_treino)

X_treino = normalizador_x.transform(X_treino)
y_treino = normalizador_y.transform(y_treino)
X_teste = normalizador_x.transform(X_teste)
y_teste = normalizador_y.transform(y_teste)

# %%
X_treino = torch.tensor(X_treino, dtype=torch.float32)
y_treino = torch.tensor(y_treino, dtype=torch.float32)
X_teste = torch.tensor(X_teste, dtype=torch.float32)
y_teste = torch.tensor(y_teste, dtype=torch.float32)

# %%
class MLP(nn.Module):
    def __init__(
        self, num_dados_entrada, neuronios_c1, neuronios_c2, num_targets
    ):
        # Temos que inicializar a classe mãe
        super().__init__()

        # Definindo as camadas da rede
        self.camadas = nn.Sequential(
                    nn.Linear(num_dados_entrada, neuronios_c1),
                    nn.ReLU(),
                    nn.Linear(neuronios_c1, neuronios_c2),
                    nn.ReLU(),
                    nn.Linear(neuronios_c2, num_targets),
                )

    def forward(self, x):
        """Esse é o método que executa a rede do pytorch."""
        x = self.camadas(x)
        return x

# %%
NUM_DADOS_DE_ENTRADA = X_treino.shape[1]
NUM_DADOS_DE_SAIDA = y_treino.shape[1]
NEURONIOS_C1 = 50
NEURONIOS_C2 = 20

minha_MLP = MLP(NUM_DADOS_DE_ENTRADA, NEURONIOS_C1, NEURONIOS_C2, NUM_DADOS_DE_SAIDA)

# %%
y_prev = minha_MLP(X_treino)

# %%
TAXA_DE_APRENDIZADO = 0.01

# função perda será o erro quadrático médio
fn_perda = nn.MSELoss()

# otimizador será o Adam, um tipo de descida do gradiente
otimizador = optim.Adam(minha_MLP.parameters(), lr=TAXA_DE_APRENDIZADO)

# %%
minha_MLP.train()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=7, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
NUM_EPOCAS = 10000

y_true = y_treino

for epoca in range(NUM_EPOCAS):
    # forward pass
    y_pred = minha_MLP(X_treino)

    # zero grad
    otimizador.zero_grad()

    # loss
    loss = fn_perda(y_pred, y_true)

    # backpropagation
    loss.backward()

    # atualiza parâmetros
    otimizador.step()

    # mostra resultado

print(epoca, loss.data)
# Out:
# 9999 tensor(0.0042)

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_treino)
    y_pred = minha_MLP(X_treino)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
minha_MLP.eval()
# Out:
# MLP(
#   (camadas): Sequential(
#     (0): Linear(in_features=7, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=2, bias=True)
#   )
# )

# %%
with torch.no_grad():
    y_true = normalizador_y.inverse_transform(y_teste)
    y_pred = minha_MLP(X_teste)
    y_pred = normalizador_y.inverse_transform(y_pred)

# %%
RMSE = mean_squared_error(y_true, y_pred, squared=False)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 19856.822305247704

# %%
RMSE = mean_squared_error(y_true, y_pred)
print(f'Loss do teste: {RMSE}')
# Out:
# Loss do teste: 476601914.73778325

# %% [markdown]
# ### Validação cruzada absorbância 1º pico

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader,TensorDataset,random_split,SubsetRandomSampler, ConcatDataset
from torch.nn import functional as F
import torchvision
from torchvision import datasets,transforms
import torchvision.transforms as transforms

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import KFold

# Defina sua classe MLP
class MLP(nn.Module):
    def __init__(self, num_dados_entrada, neuronios_c1, neuronios_c2, num_targets):
        super(MLP, self).__init__()
        self.camadas = nn.Sequential(
            nn.Linear(num_dados_entrada, neuronios_c1),
            nn.ReLU(),
            nn.Linear(neuronios_c1, neuronios_c2),
            nn.ReLU(),
            nn.Linear(neuronios_c2, num_targets)
        )

    def forward(self, x):
        x = self.camadas(x)
        return x

# Defina seus dados de entrada (X) e rótulos (y)
X = df.iloc[:,1:9].values
y = df.iloc[:,-5:-4].values

# Defina o número de folds para a validação cruzada
num_folds = 5

# Cria uma instância do KFold
kf = KFold(n_splits=num_folds, shuffle=True)

# Define a função de perda e o otimizador
criterion = nn.MSELoss()

loss_values = []

for train_indices, val_indices in kf.split(X):
    # Separa os dados de treinamento e validação para este fold
    train_X, train_y = X[train_indices], y[train_indices]
    val_X, val_y = X[val_indices], y[val_indices]

    # Cria tensores do PyTorch para os dados
    train_tensor_X = torch.Tensor(train_X)
    train_tensor_y = torch.Tensor(train_y)
    val_tensor_X = torch.Tensor(val_X)
    val_tensor_y = torch.Tensor(val_y)

    # Cria o dataloader para treinamento e validação
    train_dataset = torch.utils.data.TensorDataset(train_tensor_X, train_tensor_y)
    val_dataset = torch.utils.data.TensorDataset(val_tensor_X, val_tensor_y)
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=64, shuffle=False)

    # Cria uma instância da rede neural
    model = MLP(num_dados_entrada=train_X.shape[1], neuronios_c1=50, neuronios_c2=20, num_targets=train_y.shape[1])

    # Define o otimizador
    optimizer = optim.SGD(model.parameters(), lr=0.001)

    # Define o número de épocas de treinamento
    num_epochs = 10

    # Treina o modelo
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
        loss_values.append(epoch_loss)

    # Avalia o modelo no fold de validação
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    print(f"Accuracy for this fold: {accuracy}")
# Out:
# Accuracy for this fold: 2.0
# Accuracy for this fold: 1.0
# Accuracy for this fold: 0.0
# Accuracy for this fold: 1.0
# Accuracy for this fold: 0.0

# %%
X = df.iloc[:,1:9].values
y = df.iloc[:,-5:-4].values

model = MLP(num_dados_entrada=X.shape[1], neuronios_c1=50, neuronios_c2=20, num_targets=y.shape[1])

num_epochs = 12000

loss_values, acc_values = [], []

# Define o otimizador
optimizer = optim.SGD(model.parameters(), lr=0.001)

criterion = nn.MSELoss()

min_loss = float('inf')
min_loss_value = None

for epoch in range(num_epochs):
    model.train()
    epoch_loss,num_batches = 0.0,0  # Variável para armazenar a perda da época atual
    
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
        num_batches += 1
        
    epoch_loss /= num_batches 
    epoch_loss = np.sqrt(epoch_loss)
    
    accuracy = correct / total
    
    acc_values.append(accuracy)
    loss_values.append(epoch_loss)  # Armazena o valor da perda da época atual

    if epoch_loss < min_loss:
        min_loss = epoch_loss
        min_loss_value = outputs
        min_loss_params = model.state_dict()
        min_loss_features = inputs

print(f"Valor mínimo da perda: {round(min_loss,4)}\n")
# print(f"Valor correspondente: {min_loss_value}")

for feature_values in min_loss_features:
    print(f"Valores das features: {feature_values}")

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(range(1, num_epochs + 1), loss_values)
plt.xlabel('Época')
plt.ylabel('Perda')
plt.title('Gráfico de Perda')

plt.subplot(1,2,2)
plt.plot(range(1, num_epochs + 1), acc_values)
plt.xlabel('Época')
plt.ylabel('Accuracy')
plt.title('Gráfico de Accuracy')

plt.tight_layout()
plt.show()
# Out:
# Valor mínimo da perda: 0.1272
#
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.1429, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 1.0000, 1.0000, 0.5833, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.5000, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.4286, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 0.6667])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.2500, 0.8793, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.2500, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.2500, 0.8276, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.2000, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.2586, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 1.0000, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 1.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.8333, 1.0000, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.2857, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 0.7143, 0.0000, 0.0000])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 0.3333])
# Valores das features: tensor([0.7500, 1.0000, 1.0000, 0.5000, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 0.0667])
# Valores das features: tensor([0.2500, 0.5063, 0.5000, 0.6667, 1.0000, 1.0000, 0.0000, 0.0000])
# Valores das features: tensor([0.5000, 1.0000, 1.0000, 0.5000, 0.1724, 0.5714, 0.0000, 0.0000])
# Valores das features: tensor([1.0000, 1.0000, 1.0000, 0.5000, 0.3448, 0.5714, 1.0000, 0.0333])
